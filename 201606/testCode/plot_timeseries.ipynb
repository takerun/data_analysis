# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %pylab inline
# %run ../script/prepocessing.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Train = TemperatureData('train')
Test = TemperatureData('test')

# %%
train_temper = Train.temperVec()
test_temper = Test.temperVec()

# %%
train_temper[:,1]
# Out:
# array([-0.085799, -0.082654, -0.07951 , ..., -0.101522, -0.114101, -0.12039 ])

# %%
plt.figure(figsize=(20,6))
for i in xrange(5):
    s = 360*i
    t = 360*(i+1)
    plt.plot([j for j in xrange(360)],train_temper[s:t,1], label="year"+str(i))
plt.legend()
"""
for i in xrange(5):
    s = 360*i
    t = 360*(i+1)
    plt.plot([j for j in xrange(360)],test_temper[s:t,1], label="year"+str(i+5))

"""
# Out:
# '\nfor i in xrange(5):\n    s = 360*i\n    t = 360*(i+1)\n    plt.plot([j for j in xrange(360)],test_temper[s:t,1], label="year"+str(i+5))\n\n'

# %%
plt.figure(figsize=(20,6))
for i in xrange(11):
    plt.plot([j for j in xrange(360)],train_temper[:360,i], label="place"+str(i))
plt.legend()
plt.savefig("timeseries.eps",bbox_inches="tight", pad_inches=0.1, dpi=300,format = 'eps')

# %% [markdown]
# 周りとの分散が使えないか？

# %%
plt.figure(figsize=(20,6))
for i in xrange(11):
    plt.plot([j for j in xrange(360)],test_temper[:360,i], label="place"+str(i))
plt.legend()
